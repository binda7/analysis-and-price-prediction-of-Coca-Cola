# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from plotly import tools
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.figure_factory as ff
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data_pd = pd.read_csv('COCO_COLA.csv');

# %%
data_pd
# Out:
#              Date       Open       High        Low      Close  Adj Close  \
# 0      1962-01-02   0.263021   0.270182   0.263021   0.263021   0.051133
# 1      1962-01-03   0.259115   0.259115   0.253255   0.257161   0.049994
# 2      1962-01-04   0.257813   0.261068   0.257813   0.259115   0.050374
# 3      1962-01-05   0.259115   0.262370   0.252604   0.253255   0.049234
# 4      1962-01-08   0.251302   0.251302   0.245768   0.250651   0.048728
# ...           ...        ...        ...        ...        ...        ...
# 15091  2021-12-13  56.980000  57.930000  56.959999  57.759998  57.759998
# 15092  2021-12-14  57.400002  58.169998  57.400002  57.799999  57.799999
# 15093  2021-12-15  57.930000  58.250000  57.650002  58.060001  58.060001
# 15094  2021-12-16  57.980000  58.880001  57.900002  58.650002  58.650002
# 15095  2021-12-17  58.490002  58.919998  57.700001  57.730000  57.730000
#
#          Volume
# 0        806400
# 1       1574400
# 2        844800
# 3       1420800
# ...

# %%
data_pd.isnull().any()
# Out:
# Date         False
# Open         False
# High         False
# Low          False
# Close        False
# Adj Close    False
# Volume       False
# dtype: bool

# %%
data_pd.plot(subplots=True, figsize=(15,10))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
trace = go.Ohlc(x = data_pd['Date'],
                open = data_pd['Open'],
                high = data_pd['High'],
                low = data_pd['Low'],
                close = data_pd['Close'])

data = [trace]
iplot(data)
# Out:
# <div>                            <div id="bffa7f58-d254-460c-a03b-66c61195e475" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bffa7f58-d254-460c-a03b-66c61195e475")) {                    Plotly.newPlot(                        "bffa7f58-d254-460c-a03b-66c61195e475",                        [{"close":[0.263021,0.257161,0.259115,0.253255,0.250651,0.255208,0.25651,0.259115,0.257161,0.254557,0.25,0.242188,0.237305,0.244792,0.246745,0.241536,0.238932,0.236979,0.234375,0.234375,0.233398,0.242839,0.244792,0.247396,0.247396,0.244141,0.245443,0.246094,0.247396,0.245443,0.245443,0.240885,0.239583,0.239583,0.24349,0.242188,0.240885,0.238281,0.242188,0.24349,0.238932,0.23763,0.240234,0.236979,0.242188,0.238932,0.239583,0.236979,0.242188,0.244466,0.244792,0.2434
# ...

# %%
data_2020_2021 = data_pd.query('Date > "2020-01-01" & Date < "2020-07-01"')

# %%
trace = go.Ohlc(x = data_2020_2021['Date'],
                open = data_2020_2021['Open'],
                high = data_2020_2021['High'],
                low = data_2020_2021['Low'],
                close = data_2020_2021['Close'])

data = [trace]
iplot(data) # Widać covid-19 - opisać jakoś ładnie jak już będziesz wiedzieć
# Out:
# <div>                            <div id="04497897-6741-4a6b-bbcb-83cac5bbb8ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04497897-6741-4a6b-bbcb-83cac5bbb8ca")) {                    Plotly.newPlot(                        "04497897-6741-4a6b-bbcb-83cac5bbb8ca",                        [{"close":[54.990002,54.689999,54.669998,54.25,54.349998,55.34,55.529999,56.130001,56.0,56.700001,56.82,56.939999,57.169998,57.610001,57.830002,57.68,57.48,57.009998,57.009998,58.860001,58.400002,58.580002,58.84,58.849998,58.990002,59.189999,59.75,59.59,59.41,59.610001,59.950001,59.529999,59.77,59.720001,60.130001,58.650002,57.82,57.599998,54.93,53.490002,55.919998,56.060001,58.919998,56.740002,55.259998,51.860001,53.66,52.209999,47.16,48.470001,45.259998,47.18,44
# ...
